# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader


import sys 
sys.path.append('/home/mahakaran/NK-paper-12-5-24-version/nk-ml-paper2-2024/pscapes')
sys.path.append('/home/mahakaran/NK-paper-12-5-24-version/nk-ml-paper2-2024/nk-ml-2024')


import numpy as np
import itertools
from sklearn.utils import gen_batches

from sklearn.metrics import mean_squared_error, r2_score

import matplotlib.pyplot as plt

from torch.utils.data import Subset

from sklearn.model_selection import train_test_split
from pscapes.landscape_models import make_NK
from pscapes.landscape_class import ProteinLandscape
from pscapes.utils import dict_to_np_array

from src.architectures.testmlp import AminoAcidMLP
from src.architectures.architectures import SequenceRegressionMLP

from src.architectures.ml_utils import train_model, train_val_test_split_ohe

# %% [markdown]
# ## Testing MLP

# %%
AA_ALPHABET = 'ACDEFG'
SEQ_LENGTH  = 6
K_VALS   = list(range(SEQ_LENGTH))

# %%
NK_LANDSCAPES = [make_NK(SEQ_LENGTH, k, AA_ALPHABET, np.random.uniform) for k in K_VALS]

# %%
LANDSCAPES = [ProteinLandscape(data=dict_to_np_array(i), amino_acids=AA_ALPHABET) for i in NK_LANDSCAPES]

# %%
# %%capture

#fit one hot
[i.fit_OHE() for i in LANDSCAPES]

# %%
#MLP_params
input_size = SEQ_LENGTH * len(AA_ALPHABET)  # Total input size after flattening
input_size
# Out:
# 36

# %%
landscapes_ohe, xy_training, xy_val, xy_test, x_test, y_test = train_val_test_split_ohe(LANDSCAPES)

# %%
#instantiate models
models     = [SequenceRegressionMLP(alphabet_size=len(AA_ALPHABET), sequence_length=SEQ_LENGTH) for i in LANDSCAPES]
loss_fns   = [nn.MSELoss() for i in models]
optimizers = [optim.Adam(i.parameters(), lr=0.001) for i in models]

# %%
def get_trainable_params(model): 
    pytorch_total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return pytorch_total_params

# %%
params = [get_trainable_params(i) for i in models]

# %%
params
# Out:
# [13057, 13057, 13057, 13057, 13057, 13057]

# %%
batch_size1 = 32

# %%
TRAIN_DATALOADER = [DataLoader(i, batch_size=batch_size1) for i in xy_training]
VAL_DATALOADER   = [DataLoader(i, batch_size=batch_size1) for i in xy_val]

# %%
# Start training
losses = [train_model(models[i], optimizers[i], loss_fns[i], TRAIN_DATALOADER[i], VAL_DATALOADER[i], 
                      n_epochs=30, device='cpu', patience=8) for i in range(len(models))]
# Out:
# Epoch [1/30], Train Loss: 3.4259, Val Loss: 0.0001
# Epoch [2/30], Train Loss: 0.0381, Val Loss: 0.0000
# Epoch [3/30], Train Loss: 0.0206, Val Loss: 0.0000
# Epoch [4/30], Train Loss: 0.0116, Val Loss: 0.0000
# Epoch [5/30], Train Loss: 0.0070, Val Loss: 0.0000
# Epoch [6/30], Train Loss: 0.0056, Val Loss: 0.0000
# Epoch [7/30], Train Loss: 0.0041, Val Loss: 0.0000
# Epoch [8/30], Train Loss: 0.0047, Val Loss: 0.0000
# Epoch [9/30], Train Loss: 0.0040, Val Loss: 0.0000
# Epoch [10/30], Train Loss: 0.0039, Val Loss: 0.0000
# Epoch [11/30], Train Loss: 0.0027, Val Loss: 0.0000
# Epoch [12/30], Train Loss: 0.0028, Val Loss: 0.0000
# Epoch [13/30], Train Loss: 0.0021, Val Loss: 0.0000
# Epoch [14/30], Train Loss: 0.0028, Val Loss: 0.0000
# Epoch [15/30], Train Loss: 0.0016, Val Loss: 0.0000
# Epoch [16/30], Train Loss: 0.0020, Val Loss: 0.0000
# Epoch [17/30], Train Loss: 0.0017, Val Loss: 0.0000
# Epoch [18/30], Train Loss: 0.0017, Val Loss: 0.0000
# Epoch [19/30], Train Loss: 0.0019, Val Loss: 0.0000
# Epoch [20/30], Train Loss: 0.0016, Val Loss: 0.0000
# Epoch [21/30], Train Loss: 0.0017, Val Loss: 0.0000
# Epoch [22/30], Train Loss: 0.0024, Val Loss: 0.0000
# Epoch [23/30], Train Loss: 0.0014, Val Loss: 0.0000
# Epoch [24/30], Train Loss: 0.0012, Val Loss: 0.0000
# Epoch [25/30], Train Loss: 0.0016, Val Loss: 0.0000
# Early stopping triggered
# /home/mahakaran/NK-paper-12-5-24-version/nk-ml-paper2-2024/nk-ml-2024/src/architectures/ml_utils.py:91: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(early_stopping.path))
# Epoch [1/30], Train Loss: 7.0539, Val Loss: 0.0006
# Epoch [2/30], Train Loss: 0.4246, Val Loss: 0.0004
# Epoch [3/30], Train Loss: 0.2642, Val Loss: 0.0003
# Epoch [4/30], Train Loss: 0.1917, Val Loss: 0.0002
# Epoch [5/30], Train Loss: 0.1420, Val Loss: 0.0002
# Epoch [6/30], Train Loss: 0.1134, Val Loss: 0.0001
# Epoch [7/30], Train Loss: 0.0944, Val Loss: 0.0001
# Epoch [8/30], Train Loss: 0.0815, Val Loss: 0.0002
# Epoch [9/30], Train Loss: 0.0717, Val Loss: 0.0002
# Epoch [10/30], Train Loss: 0.0621, Val Loss: 0.0001
# Epoch [11/30], Train Loss: 0.0551, Val Loss: 0.0001
# Epoch [12/30], Train Loss: 0.0531, Val Loss: 0.0001
# Epoch [13/30], Train Loss: 0.0532, Val Loss: 0.0001
# Epoch [14/30], Train Loss: 0.0473, Val Loss: 0.0001
# Epoch [15/30], Train Loss: 0.0325, Val Loss: 0.0001
# Epoch [16/30], Train Loss: 0.0292, Val Loss: 0.0001
# Epoch [17/30], Train Loss: 0.0316, Val Loss: 0.0001
# Epoch [18/30], Train Loss: 0.0360, Val Loss: 0.0000
# Epoch [19/30], Train Loss: 0.0229, Val Loss: 0.0000
# Epoch [20/30], Train Loss: 0.0319, Val Loss: 0.0000
# Epoch [21/30], Train Loss: 0.0197, Val Loss: 0.0000
# Epoch [22/30], Train Loss: 0.0192, Val Loss: 0.0000
# Epoch [23/30], Train Loss: 0.0318, Val Loss: 0.0000
# Epoch [24/30], Train Loss: 0.0149, Val Loss: 0.0000
# Epoch [25/30], Train Loss: 0.0170, Val Loss: 0.0000
# Epoch [26/30], Train Loss: 0.0195, Val Loss: 0.0001
# Epoch [27/30], Train Loss: 0.0147, Val Loss: 0.0000
# Epoch [28/30], Train Loss: 0.0150, Val Loss: 0.0000
# Epoch [29/30], Train Loss: 0.0180, Val Loss: 0.0000
# Epoch [30/30], Train Loss: 0.0150, Val Loss: 0.0000
# Epoch [1/30], Train Loss: 13.3460, Val Loss: 0.0097
# Epoch [2/30], Train Loss: 7.1420, Val Loss: 0.0059
# Epoch [3/30], Train Loss: 3.9480, Val Loss: 0.0031
# Epoch [4/30], Train Loss: 2.2078, Val Loss: 0.0019
# Epoch [5/30], Train Loss: 1.3842, Val Loss: 0.0018
# Epoch [6/30], Train Loss: 1.0076, Val Loss: 0.0016
# Epoch [7/30], Train Loss: 0.8040, Val Loss: 0.0019
# Epoch [8/30], Train Loss: 0.6613, Val Loss: 0.0013
# Epoch [9/30], Train Loss: 0.5677, Val Loss: 0.0012
# Epoch [10/30], Train Loss: 0.5049, Val Loss: 0.0011
# Epoch [11/30], Train Loss: 0.4400, Val Loss: 0.0009
# Epoch [12/30], Train Loss: 0.3971, Val Loss: 0.0010
# Epoch [13/30], Train Loss: 0.3648, Val Loss: 0.0006
# Epoch [5/30], Train Loss: 16.8865, Val Loss: 0.0186
# Epoch [6/30], Train Loss: 16.5296, Val Loss: 0.0185
# Epoch [7/30], Train Loss: 16.0679, Val Loss: 0.0184
# Epoch [8/30], Train Loss: 15.5807, Val Loss: 0.0183
# Epoch [9/30], Train Loss: 15.0856, Val Loss: 0.0182
# Epoch [10/30], Train Loss: 14.6233, Val Loss: 0.0182
# Epoch [11/30], Train Loss: 14.2019, Val Loss: 0.0182
# Epoch [12/30], Train Loss: 13.7730, Val Loss: 0.0182
# Epoch [13/30], Train Loss: 13.3580, Val Loss: 0.0183
# Epoch [14/30], Train Loss: 12.9794, Val Loss: 0.0184
# Epoch [15/30], Train Loss: 12.6384, Val Loss: 0.0184
# Epoch [16/30], Train Loss: 12.3287, Val Loss: 0.0184
# Epoch [17/30], Train Loss: 12.0168, Val Loss: 0.0185
# Early stopping triggered
# Epoch [1/30], Train Loss: 18.2447, Val Loss: 0.0191
# Epoch [2/30], Train Loss: 17.2924, Val Loss: 0.0191
# Epoch [3/30], Train Loss: 17.1784, Val Loss: 0.0191
# Epoch [4/30], Train Loss: 17.0890, Val Loss: 0.0191
# Epoch [5/30], Train Loss: 16.9998, Val Loss: 0.0191
# Epoch [6/30], Train Loss: 16.9084, Val Loss: 0.0192
# Epoch [7/30], Train Loss: 16.8198, Val Loss: 0.0193
# Epoch [8/30], Train Loss: 16.7102, Val Loss: 0.0194
# Epoch [9/30], Train Loss: 16.6036, Val Loss: 0.0193
# Epoch [10/30], Train Loss: 16.4967, Val Loss: 0.0194
# Epoch [11/30], Train Loss: 16.3623, Val Loss: 0.0196
# Early stopping triggered

# %%
losses2 = [i[-1] for i in losses]

# %%
fig,ax = plt.subplots(nrows=2, ncols=3, figsize=(15, 7))
ax[0,0].plot(losses2[0])
ax[0,1].plot(losses2[1])
ax[0,2].plot(losses2[2])
ax[1,0].plot(losses2[3])
ax[1,1].plot(losses2[4])
ax[1,2].plot(losses2[5])




#for i in ax.flatten():
    #i.set_ylim(0,0.01)

# %%
TEST_PREDS = [models[i](x_test[i]).detach() for i in range(len(models))]

# %%
Y_TEST=y_test
r2_losses = [r2_score(TEST_PREDS[i].detach(), Y_TEST[i].detach()) for i in range(len(TEST_PREDS))]

# %%
fig,ax = plt.subplots(nrows=2, ncols=3, figsize=(15, 7))
ax[0,0].scatter(TEST_PREDS[0], Y_TEST[0],marker='.', s=.3)
ax[0,1].scatter(TEST_PREDS[1], Y_TEST[1],marker='.', s=.3)
ax[0,2].scatter(TEST_PREDS[2], Y_TEST[2],marker='.', s=.3)
ax[1,0].scatter(TEST_PREDS[3], Y_TEST[3],marker='.', s=.3)
ax[1,1].scatter(TEST_PREDS[4], Y_TEST[4],marker='.', s=.3)
ax[1,2].scatter(TEST_PREDS[5], Y_TEST[5],marker='.', s=.3)



for ind, i in enumerate(ax.flatten()):
    i.set_title("$R^2 = $" + str(r2_losses[ind]))

# %%
# Variable to store the output of the layer
layer_output = []

# Define a hook function to capture the output
def hook_fn(module, input, output):
    layer_outputs.append(output)

# Register the hook to the conv1 layer
hook = models[0].fc_layers[-1].register_forward_hook(hook_fn)

# %%
layer_outputs = [] 
hooks = [i.fc_layers[-1].register_forward_hook(hook_fn) for i in models]

# %%
landscapes_as_tensor = [torch.from_numpy(i).to(torch.float32) for i in landscapes_ohe]

# %%
model_forward_output = [models[i](landscapes_as_tensor[i]) for i in range(len(models))]

# %%
layer_outputs
# Out:
# []
