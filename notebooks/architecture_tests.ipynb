# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader


import sys 
sys.path.append('/home/mahakaran/NK-paper-12-5-24-version/nk-ml-paper2-2024/pscapes')
sys.path.append('/home/mahakaran/NK-paper-12-5-24-version/nk-ml-paper2-2024/nk-ml-2024')


import numpy as np
import itertools
from sklearn.utils import gen_batches

from sklearn.metrics import mean_squared_error, r2_score

import matplotlib.pyplot as plt

from torch.utils.data import Subset

from sklearn.model_selection import train_test_split
from pscapes.landscape_models import make_NK
from pscapes.landscape_class import Protein_Landscape
from pscapes.utils import dict_to_np_array

from src.architectures.ml_utils import train_val_test_split_ohe, train_model, get_trainable_params

from src.architectures.architectures import SequenceRegressionLSTM
#from src.architectures.ml_utils import train_model

# %%
AA_ALPHABET = 'ACDEFG'
SEQ_LENGTH  = 6
K_VALS   = list(range(SEQ_LENGTH))

# %%
NK_LANDSCAPES = [make_NK(SEQ_LENGTH, k, AA_ALPHABET, np.random.uniform) for k in K_VALS]

# %%
LANDSCAPES = [Protein_Landscape(data=dict_to_np_array(i), amino_acids=AA_ALPHABET) for i in NK_LANDSCAPES]

# %%
# %%capture

#fit one hot
[i.fit_OHE() for i in LANDSCAPES]

# %%
#MLP_params
input_size = SEQ_LENGTH * len(AA_ALPHABET)  # Total input size after flattening
input_size
# Out:
# 36

# %%
landscapes_ohe, xy_train, xy_val, xy_test, x_test, y_test = train_val_test_split_ohe(LANDSCAPES)

# %%
#instantiate models
models     = [SequenceRegressionLSTM(input_size=len(AA_ALPHABET), bidirectional=True) for i in LANDSCAPES]
loss_fns   = [nn.MSELoss() for i in models]
optimizers = [optim.Adam(i.parameters(), lr=0.001) for i in models]

# %%
print(len(xy_train[0]))
print(len(xy_val[0]))
print(len(xy_test[0]))
# Out:
# 29860
# 7465
# 9331

# %%
batch_size1 = 32
TRAIN_DATALOADER = [DataLoader(i, batch_size=batch_size1) for i in xy_train]
VAL_DATALOADER   = [DataLoader(i, batch_size=batch_size1) for i in xy_val]

# %%
params = [get_trainable_params(i) for i in models]
params
# Out:
# [534785, 534785, 534785, 534785, 534785, 534785]

# %%
# Start training
models_outs = [train_model(models[i], optimizers[i], loss_fns[i], TRAIN_DATALOADER[i], VAL_DATALOADER[i], n_epochs=50, device='cpu', patience=5) for i in range(len(models))]
# Out:
# Epoch [1/50], Train Loss: 6.0235, Val Loss: 0.0000
# Epoch [2/50], Train Loss: 0.0285, Val Loss: 0.0000
# Epoch [3/50], Train Loss: 0.0160, Val Loss: 0.0000
# Epoch [4/50], Train Loss: 0.0185, Val Loss: 0.0000
# Epoch [5/50], Train Loss: 0.0170, Val Loss: 0.0000
# Epoch [6/50], Train Loss: 0.0158, Val Loss: 0.0000
# Epoch [7/50], Train Loss: 0.0227, Val Loss: 0.0000
# Epoch [8/50], Train Loss: 0.0117, Val Loss: 0.0000
# Epoch [9/50], Train Loss: 0.0241, Val Loss: 0.0000
# Epoch [10/50], Train Loss: 0.0106, Val Loss: 0.0000
# Epoch [11/50], Train Loss: 0.0109, Val Loss: 0.0000
# Epoch [12/50], Train Loss: 0.0149, Val Loss: 0.0000
# Epoch [13/50], Train Loss: 0.0142, Val Loss: 0.0000
# Epoch [14/50], Train Loss: 0.0156, Val Loss: 0.0000
# Epoch [15/50], Train Loss: 0.0073, Val Loss: 0.0000
# Epoch [16/50], Train Loss: 0.0064, Val Loss: 0.0001
# Epoch [17/50], Train Loss: 0.0104, Val Loss: 0.0000
# Epoch [18/50], Train Loss: 0.0083, Val Loss: 0.0000
# Epoch [19/50], Train Loss: 0.0097, Val Loss: 0.0000
# Epoch [20/50], Train Loss: 0.0092, Val Loss: 0.0000
# Epoch [21/50], Train Loss: 0.0068, Val Loss: 0.0000
# Epoch [22/50], Train Loss: 0.0117, Val Loss: 0.0000
# Epoch [23/50], Train Loss: 0.0055, Val Loss: 0.0000
# Early stopping triggered
# /home/mahakaran/NK-paper-12-5-24-version/nk-ml-paper2-2024/nk-ml-2024/src/architectures/ml_utils.py:91: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(early_stopping.path))
# Epoch [1/50], Train Loss: 19.4211, Val Loss: 0.0170
# Epoch [2/50], Train Loss: 11.5770, Val Loss: 0.0072
# Epoch [3/50], Train Loss: 3.8515, Val Loss: 0.0019
# Epoch [4/50], Train Loss: 0.9950, Val Loss: 0.0005
# Epoch [5/50], Train Loss: 0.3553, Val Loss: 0.0003
# Epoch [6/50], Train Loss: 0.2239, Val Loss: 0.0002
# Epoch [7/50], Train Loss: 0.1759, Val Loss: 0.0002
# Epoch [8/50], Train Loss: 0.1600, Val Loss: 0.0002
# Epoch [9/50], Train Loss: 0.1438, Val Loss: 0.0002
# Epoch [10/50], Train Loss: 0.1297, Val Loss: 0.0002
# Epoch [11/50], Train Loss: 0.1195, Val Loss: 0.0001
# Epoch [12/50], Train Loss: 0.1132, Val Loss: 0.0001
# Epoch [13/50], Train Loss: 0.1091, Val Loss: 0.0001
# Epoch [14/50], Train Loss: 0.1036, Val Loss: 0.0001
# Epoch [15/50], Train Loss: 0.0907, Val Loss: 0.0001
# Epoch [16/50], Train Loss: 0.0830, Val Loss: 0.0001
# Epoch [17/50], Train Loss: 0.0756, Val Loss: 0.0001
# Epoch [18/50], Train Loss: 0.0704, Val Loss: 0.0001
# Epoch [19/50], Train Loss: 0.0680, Val Loss: 0.0001
# Epoch [20/50], Train Loss: 0.0637, Val Loss: 0.0001
# Epoch [21/50], Train Loss: 0.0607, Val Loss: 0.0001
# Epoch [22/50], Train Loss: 0.0585, Val Loss: 0.0001
# Epoch [23/50], Train Loss: 0.0637, Val Loss: 0.0001
# Epoch [24/50], Train Loss: 0.0573, Val Loss: 0.0001
# Epoch [25/50], Train Loss: 0.0496, Val Loss: 0.0001
# Early stopping triggered
# Epoch [1/50], Train Loss: 18.5296, Val Loss: 0.0182
# Epoch [2/50], Train Loss: 16.7688, Val Loss: 0.0172
# Epoch [3/50], Train Loss: 15.6102, Val Loss: 0.0163
# Epoch [4/50], Train Loss: 14.7328, Val Loss: 0.0156
# Epoch [5/50], Train Loss: 13.6542, Val Loss: 0.0142
# Epoch [6/50], Train Loss: 12.1228, Val Loss: 0.0125
# Epoch [7/50], Train Loss: 10.0906, Val Loss: 0.0105
# Epoch [8/50], Train Loss: 7.9688, Val Loss: 0.0086
# Epoch [9/50], Train Loss: 6.2066, Val Loss: 0.0067
# Epoch [10/50], Train Loss: 4.8104, Val Loss: 0.0055
# Epoch [11/50], Train Loss: 3.7208, Val Loss: 0.0044
# Epoch [12/50], Train Loss: 2.8280, Val Loss: 0.0034
# Epoch [13/50], Train Loss: 2.1450, Val Loss: 0.0027
# Epoch [14/50], Train Loss: 1.6487, Val Loss: 0.0022
# Epoch [15/50], Train Loss: 1.3008, Val Loss: 0.0019
# Epoch [16/50], Train Loss: 1.0543, Val Loss: 0.0017
# Epoch [17/50], Train Loss: 0.8729, Val Loss: 0.0015
# Epoch [18/50], Train Loss: 0.7367, Val Loss: 0.0014
# Epoch [19/50], Train Loss: 0.6333, Val Loss: 0.0013
# Epoch [20/50], Train Loss: 0.5544, Val Loss: 0.0012
# Epoch [21/50], Train Loss: 0.4971, Val Loss: 0.0011
# Epoch [22/50], Train Loss: 0.4594, Val Loss: 0.0011
# Epoch [23/50], Train Loss: 0.4367, Val Loss: 0.0011
# Epoch [24/50], Train Loss: 0.4264, Val Loss: 0.0011
# Epoch [25/50], Train Loss: 0.4276, Val Loss: 0.0011
# Epoch [26/50], Train Loss: 0.4206, Val Loss: 0.0011
# Epoch [27/50], Train Loss: 0.3972, Val Loss: 0.0011
# Epoch [28/50], Train Loss: 0.3723, Val Loss: 0.0011
# Epoch [29/50], Train Loss: 0.3568, Val Loss: 0.0011
# Epoch [30/50], Train Loss: 0.3494, Val Loss: 0.0010
# Epoch [31/50], Train Loss: 0.3451, Val Loss: 0.0009
# Epoch [32/50], Train Loss: 0.3305, Val Loss: 0.0009
# Epoch [33/50], Train Loss: 0.3039, Val Loss: 0.0010
# Epoch [34/50], Train Loss: 0.2798, Val Loss: 0.0010
# Epoch [35/50], Train Loss: 0.2607, Val Loss: 0.0010
# Epoch [36/50], Train Loss: 0.2527, Val Loss: 0.0009
# Epoch [37/50], Train Loss: 0.2649, Val Loss: 0.0009
# Epoch [38/50], Train Loss: 0.2962, Val Loss: 0.0009
# Epoch [39/50], Train Loss: 0.2988, Val Loss: 0.0010
# Epoch [40/50], Train Loss: 0.2789, Val Loss: 0.0012
# Epoch [41/50], Train Loss: 0.2458, Val Loss: 0.0011
# Epoch [42/50], Train Loss: 0.2102, Val Loss: 0.0010
# Epoch [43/50], Train Loss: 0.1918, Val Loss: 0.0009
# Early stopping triggered
# Epoch [1/50], Train Loss: 20.2621, Val Loss: 0.0200
# Epoch [2/50], Train Loss: 18.6219, Val Loss: 0.0197
# Epoch [3/50], Train Loss: 18.3968, Val Loss: 0.0195
# Epoch [4/50], Train Loss: 18.1631, Val Loss: 0.0193
# Epoch [5/50], Train Loss: 17.9324, Val Loss: 0.0191
# Epoch [6/50], Train Loss: 17.6964, Val Loss: 0.0189
# Epoch [7/50], Train Loss: 17.4014, Val Loss: 0.0186
# Epoch [8/50], Train Loss: 17.0090, Val Loss: 0.0182
# Epoch [9/50], Train Loss: 16.5487, Val Loss: 0.0178
# Epoch [10/50], Train Loss: 15.9000, Val Loss: 0.0171
# Epoch [11/50], Train Loss: 15.0150, Val Loss: 0.0164
# Epoch [12/50], Train Loss: 13.9581, Val Loss: 0.0156
# Epoch [13/50], Train Loss: 12.7941, Val Loss: 0.0146
# Epoch [14/50], Train Loss: 11.5582, Val Loss: 0.0136
# Epoch [15/50], Train Loss: 10.2685, Val Loss: 0.0125
# Epoch [16/50], Train Loss: 9.0098, Val Loss: 0.0115
# Epoch [17/50], Train Loss: 7.8232, Val Loss: 0.0104
# Epoch [18/50], Train Loss: 6.6940, Val Loss: 0.0093
# Epoch [19/50], Train Loss: 5.6367, Val Loss: 0.0084
# Epoch [20/50], Train Loss: 4.6958, Val Loss: 0.0075
# Epoch [21/50], Train Loss: 3.8875, Val Loss: 0.0067
# Epoch [22/50], Train Loss: 3.2144, Val Loss: 0.0061
# Epoch [23/50], Train Loss: 2.6714, Val Loss: 0.0056
# Epoch [24/50], Train Loss: 2.2408, Val Loss: 0.0052
# Epoch [25/50], Train Loss: 1.8988, Val Loss: 0.0049
# Epoch [26/50], Train Loss: 1.6239, Val Loss: 0.0046
# Epoch [27/50], Train Loss: 1.4004, Val Loss: 0.0045
# Epoch [28/50], Train Loss: 1.2219, Val Loss: 0.0044
# Epoch [29/50], Train Loss: 1.0854, Val Loss: 0.0043
# Epoch [30/50], Train Loss: 0.9889, Val Loss: 0.0042
# Epoch [31/50], Train Loss: 0.9364, Val Loss: 0.0042
# Epoch [32/50], Train Loss: 0.9264, Val Loss: 0.0042
# Epoch [33/50], Train Loss: 0.9313, Val Loss: 0.0041
# Epoch [34/50], Train Loss: 0.9440, Val Loss: 0.0041
# Epoch [35/50], Train Loss: 0.9438, Val Loss: 0.0041
# Epoch [36/50], Train Loss: 0.8731, Val Loss: 0.0040
# Epoch [37/50], Train Loss: 0.7878, Val Loss: 0.0039
# Epoch [38/50], Train Loss: 0.7071, Val Loss: 0.0040
# Epoch [39/50], Train Loss: 0.6566, Val Loss: 0.0041
# Epoch [40/50], Train Loss: 0.6446, Val Loss: 0.0041
# Epoch [41/50], Train Loss: 0.6577, Val Loss: 0.0040
# Epoch [42/50], Train Loss: 0.6837, Val Loss: 0.0042
# Early stopping triggered
# Epoch [1/50], Train Loss: 20.3638, Val Loss: 0.0205
# Epoch [2/50], Train Loss: 19.4414, Val Loss: 0.0205
# Epoch [3/50], Train Loss: 19.3719, Val Loss: 0.0205
# Epoch [4/50], Train Loss: 19.3262, Val Loss: 0.0205
# Epoch [5/50], Train Loss: 19.2897, Val Loss: 0.0205
# Epoch [6/50], Train Loss: 19.2506, Val Loss: 0.0205
# Epoch [7/50], Train Loss: 19.2118, Val Loss: 0.0205
# Early stopping triggered
# Epoch [1/50], Train Loss: 19.3356, Val Loss: 0.0196
# Epoch [2/50], Train Loss: 18.1622, Val Loss: 0.0196
# Epoch [3/50], Train Loss: 18.0822, Val Loss: 0.0196
# Epoch [4/50], Train Loss: 18.0425, Val Loss: 0.0197
# Epoch [5/50], Train Loss: 18.0166, Val Loss: 0.0197
# Epoch [6/50], Train Loss: 17.9969, Val Loss: 0.0197
# Early stopping triggered

# %%
[1,2,3,4][-2:]
# Out:
# [3, 4]

# %%
losses = [i[1] for i in models_outs]
fig,ax = plt.subplots(nrows=2, ncols=3, figsize=(15, 7))
ax[0,0].plot(losses[0])
ax[0,1].plot(losses[1])
ax[0,2].plot(losses[2])
ax[1,0].plot(losses[3])
ax[1,1].plot(losses[4])
ax[1,2].plot(losses[5])

# %%
TEST_PREDS = [models[i](x_test[i]).detach() for i in range(len(models))]
r2_losses = [r2_score(TEST_PREDS[i].detach(), y_test[i].detach()) for i in range(len(TEST_PREDS))]

# %%
fig,ax = plt.subplots(nrows=2, ncols=3, figsize=(15, 7))
ax[0,0].scatter(TEST_PREDS[0], y_test[0],marker='.', s=.3)
ax[0,1].scatter(TEST_PREDS[1], y_test[1],marker='.', s=.3)
ax[0,2].scatter(TEST_PREDS[2], y_test[2],marker='.', s=.3)
ax[1,0].scatter(TEST_PREDS[3], y_test[3],marker='.', s=.3)
ax[1,1].scatter(TEST_PREDS[4], y_test[4],marker='.', s=.3)
ax[1,2].scatter(TEST_PREDS[5], y_test[5],marker='.', s=.3)



for ind, i in enumerate(ax.flatten()):
    i.set_title("$R^2 = $" + str(r2_losses[ind]))
    i.set_xlim(0,1)
    i.set_ylim(0,1)

# %% [markdown]
# Let's keep training the last two models to see if we can get better performance

# %%
for i in [1,2,3,4][-2:]:
    print(i)
# Out:
# 3
# 4
